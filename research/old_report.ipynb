# %% [markdown]
# # Precision Volatility Forecasting for Strategic Quote Placement in High-Frequency Trading

# %%
# check python version
# automatically installs dependencies if they’re not already installed 
# from install_packages import install_dependencies, check_python_version
# check_python_version()
# install_dependencies()

# %%
import os
import pandas as pd
import numpy as np
import random
import importlib
import time
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf

import models.util as util
importlib.reload(util)
# Out:
# <module 'models.util' from '/Users/kang/Projects/volatility-analysis/models/util.py'>

# %%
# Set random seed for reproducibility
SEED = 3888
np.random.seed(SEED)
random.seed(SEED)

# set seed for lstm
tf.random.set_seed(SEED)

# %%
# Set path to local data directory
folder_path = "data"
feature_path = os.path.join(folder_path, "order_book_feature.parquet")
target_path = os.path.join(folder_path, "order_book_target.parquet")

# Load and combine parquet files
feature_df = pd.read_parquet(feature_path, engine='pyarrow')
target_df = pd.read_parquet(target_path, engine='pyarrow')
combined_df = pd.concat([feature_df, target_df], axis=0)
combined_df = combined_df.sort_values(by=['stock_id', 'time_id', 'seconds_in_bucket']).reset_index(drop=True)

# Load time reference
time_ref_path = os.path.join(folder_path, "time_id_reference.csv")
time_ref_df = pd.read_csv(time_ref_path)
time_ref_df["datetime"] = pd.to_datetime(time_ref_df["date"] + " " + time_ref_df["time"])

# Filter one stock for now
df_single_stock = combined_df[combined_df["stock_id"] == 50200].copy()

# Step 1: Compute snapshot features
snapshot_features_df = util.create_snapshot_features(df_single_stock)

# Step 2: Compute rolling-window training set
rolling_features_df = util.generate_rolling_features(snapshot_features_df)

# Merge time_id to datetime (optional for plotting/debugging)
rolling_features_df = pd.merge(
    rolling_features_df.drop(columns=["datetime"], errors="ignore"),
    time_ref_df[["time_id", "datetime"]],
    on="time_id",
    how="left"
)

# Preview
print("Rolling features:", rolling_features_df.shape)
display(rolling_features_df.head())

print("Rolling features:", snapshot_features_df.shape)
display(snapshot_features_df.head())
# Out:
# Rolling features: (833290, 25)
#    stock_id  time_id  start_time    wap_mean   wap_std     wap_max  \
# 0   50200.0      6.0      1800.0  372.347747  0.152688  372.598023
# 1   50200.0      6.0      1802.0  372.340905  0.156816  372.598023
# 2   50200.0      6.0      1805.0  372.332872  0.163290  372.598023
# 3   50200.0      6.0      1807.0  372.326948  0.165921  372.598023
# 4   50200.0      6.0      1810.0  372.319845  0.168082  372.598023
#
#       wap_min  spread_pct_mean  spread_pct_std  spread_pct_max  ...  \
# 0  372.036666         0.000037        0.000013        0.000054  ...
# 1  371.955111         0.000038        0.000013        0.000054  ...
# 2  371.934998         0.000038        0.000013        0.000054  ...
# 3  371.934998         0.000037        0.000013        0.000054  ...
# 4  371.934998         0.000037        0.000013        0.000054  ...
#
#    depth_ratio_mean  depth_ratio_std  depth_ratio_max  depth_ratio_min  \
# 0          7.589939        44.479523       395.999604         0.033333
# 1          7.582752        44.480654       395.999604         0.033333
# 2          7.566621        44.482415       395.999604         0.033333
# 3          7.510483        44.485172       395.999604         0.033333
# 4          7.508179        44.485539       395.999604         0.033333
#
#    log_return_mean  log_return_std  log_return_max  log_return_min  \
# 0        -0.000003        0.000046        0.000159       -0.000207
# 1        -0.000004        0.000048        0.000159       -0.000219
# 2        -0.000004        0.000048        0.000159       -0.000219
# 3        -0.000004        0.000051        0.000340       -0.000219
# 4        -0.000004        0.000050        0.000340       -0.000219
#
#    realized_volatility  datetime
# 0             0.000235       NaT
# 1             0.000356       NaT
# 2             0.000357       NaT
# 3             0.000162       NaT
# 4             0.000179       NaT
#
# [5 rows x 25 columns]
# Rolling features: (4166788, 18)
#           stock_id  time_id  seconds_in_bucket  bid_price1  ask_price1  \
# 27224315     50200        6             1800.0      372.48      372.50
# 27224316     50200        6             1800.0      372.48      372.50
# 27224317     50200        6             1801.0      372.47      372.48
# 27224318     50200        6             1801.0      372.47      372.48
# 27224319     50200        6             1802.0      372.46      372.47
#
#           bid_price2  ask_price2  bid_size1  ask_size1  bid_size2  ask_size2  \
# 27224315      372.47      372.51        200        200       1408        510
# 27224316      372.47      372.51        200        200       1408        510
# 27224317      372.46      372.49        435        830        608        300
# 27224318      372.46      372.49        435        830        608        300
# 27224319      372.45      372.48        100        100        508       1500
#
#           mid_price         wap  bid_ask_spread  spread_pct  imbalance  \
# 27224315    372.490  372.489999            0.02    0.000054   0.000000
# 27224316    372.490  372.489999            0.02    0.000054   0.000000
# 27224317    372.475  372.473438            0.01    0.000027  -0.312253
# 27224318    372.475  372.473438            0.01    0.000027  -0.312253
# 27224319    372.465  372.464998            0.01    0.000027   0.000000
#
#           depth_ratio  log_return
# 27224315     1.000000    0.000000
# 27224316     1.000000    0.000000
# 27224317     0.524096   -0.000044
# 27224318     0.524096    0.000000
# 27224319     1.000000   -0.000023

# %%
# Import and reload HAR-RV model
# import function from models/har_rv.py
import models.har_rv as har_rv
importlib.reload(har_rv)

# Fit HAR-RV OLS model and track computation time
start_time = time.time()
model_rv_ols, test_df_ols = har_rv.ols(rolling_features_df)
ols_time = time.time() - start_time
print(f"HAR-RV OLS training completed in {ols_time:.2f} seconds.")

# Plot predicted vs. actual volatility for one time_id
util.plot_prediction_vs_actual(
    df=test_df_ols,
    time_id=test_df_ols['time_id'].iloc[0],
    y_true_col='realized_volatility',
    y_pred_col='y_pred'
)
# Out:
# python(13767) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# === HAR-RV OLS Baseline Evaluation ===
# MSE: 0.00000001
# RMSE: 0.00010876
# QLIKE: 0.6665
# Directional Accuracy: 0.5070
# ✅ Model saved to models/out/harrv/har_ols.pkl
# HAR-RV OLS training completed in 0.29 seconds.

# %%
# Fit HAR-RV WLS model and track computation time
start_time = time.time()
model_wls, test_df_wls = har_rv.wls(rolling_features_df)
ols_time = time.time() - start_time
print(f"HAR-RV WLS training completed in {ols_time:.2f} seconds.")

# Plot predicted vs. actual volatility for one time_id
util.plot_prediction_vs_actual(
    df=test_df_wls,
    time_id=test_df_wls['time_id'].iloc[0],
    y_true_col='realized_volatility',
    y_pred_col='y_pred'
)
# Out:
# === HAR-RV WLS Baseline Evaluation ===
# MSE: 0.00000001
# RMSE: 0.00011779
# QLIKE: 0.8773
# Directional Accuracy: 0.4819
# ✅ Model saved to models/out/harrv/har_wls.pkl
# HAR-RV WLS training completed in 0.38 seconds.

# %%
import models.lstm as lstm
importlib.reload(lstm)

subset_time_ids = snapshot_features_df['time_id'].unique()[:100]
df_subset = snapshot_features_df[snapshot_features_df['time_id'].isin(subset_time_ids)].copy()
lstm_df = util.generate_tick_sequences(df_subset, feature_cols=["wap","spread_pct","imbalance","depth_ratio","log_return"])

# %%
importlib.reload(lstm)
model_lstm_baseline, history_lstm_baseline, test_df_lstm_baseline = lstm.baseline(lstm_df)
# Out:
# 2025-05-16 23:14:02.652298: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-05-16 23:14:02.652521: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2025-05-16 23:14:02.652542: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2025-05-16 23:14:02.652576: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-16 23:14:02.652648: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/50
# 2025-05-16 23:14:04.244193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 53s 31ms/step - loss: 0.8003 - val_loss: 0.8642 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5766 - val_loss: 0.8058 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5646 - val_loss: 0.7973 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5594 - val_loss: 0.7947 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5564 - val_loss: 0.7924 - learning_rate: 1.0000e-04
# Epoch 6/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5529 - val_loss: 0.7848 - learning_rate: 1.0000e-04
# Epoch 7/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5492 - val_loss: 0.7900 - learning_rate: 1.0000e-04
# Epoch 8/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5492 - val_loss: 0.7895 - learning_rate: 1.0000e-04
# Epoch 9/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.5478 - val_loss: 0.7843 - learning_rate: 1.0000e-04
# Epoch 10/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5482 - val_loss: 0.7919 - learning_rate: 1.0000e-04
# Epoch 11/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.5453 - val_loss: 0.7912 - learning_rate: 1.0000e-04
# Epoch 12/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 49s 30ms/step - loss: 0.5431 - val_loss: 0.7819 - learning_rate: 1.0000e-04
# Epoch 13/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.5444 - val_loss: 0.7773 - learning_rate: 1.0000e-04
# Epoch 14/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.5392 - val_loss: 0.7835 - learning_rate: 1.0000e-04
# Epoch 15/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.5396 - val_loss: 0.7525 - learning_rate: 1.0000e-04
# Epoch 16/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.5386 - val_loss: 0.7775 - learning_rate: 1.0000e-04
# Epoch 17/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5377 - val_loss: 0.7768 - learning_rate: 1.0000e-04
# Epoch 18/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5368 - val_loss: 0.7703 - learning_rate: 1.0000e-04
# Epoch 19/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5365 - val_loss: 0.7678 - learning_rate: 1.0000e-04
# Epoch 20/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5358 - val_loss: 0.7618 - learning_rate: 1.0000e-04
# Epoch 21/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5336 - val_loss: 0.7598 - learning_rate: 5.0000e-05
# Epoch 22/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5301 - val_loss: 0.7613 - learning_rate: 5.0000e-05
# Epoch 23/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5320 - val_loss: 0.7639 - learning_rate: 5.0000e-05
# Epoch 24/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5299 - val_loss: 0.7671 - learning_rate: 5.0000e-05
# Epoch 25/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - loss: 0.5295 - val_loss: 0.7630 - learning_rate: 5.0000e-05
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === Final Evaluation ===
# MSE: 0.00000000
# RMSE: 0.00005953
# QLIKE: 0.3583
# Directional Accuracy: 0.3508
# ✅ Model saved to models/out/lstm/lstm_baseline.h5
# ✅ Scalers saved to models/out/lstm/lstm_baseline_scalers.pkl

# %%
#test_df_lstm['time_id'].iloc[1]

util.plot_prediction_vs_actual(
    df=test_df_lstm_baseline,
    time_id=test_df_lstm_baseline['time_id'].iloc[1],
    y_true_col="y_true",
    y_pred_col="y_pred"
)

util.plot_training_loss(history_lstm_baseline)

# %%
model_lstm_v256d03, history_lstm_v256d03, test_df_lstm_v256d03 = lstm.config_v256d03(lstm_df)
# Out:
# Epoch 1/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - loss: 0.7413 - val_loss: 0.7579 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5720 - val_loss: 0.7359 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5649 - val_loss: 0.7427 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5601 - val_loss: 0.7466 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5566 - val_loss: 0.7798 - learning_rate: 1.0000e-04
# Epoch 6/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5532 - val_loss: 0.7783 - learning_rate: 1.0000e-04
# Epoch 7/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5487 - val_loss: 0.7992 - learning_rate: 1.0000e-04
# Epoch 8/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5404 - val_loss: 0.7722 - learning_rate: 5.0000e-05
# Epoch 9/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - loss: 0.5393 - val_loss: 0.7801 - learning_rate: 5.0000e-05
# Epoch 10/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - loss: 0.5359 - val_loss: 0.7726 - learning_rate: 5.0000e-05
# Epoch 11/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - loss: 0.5359 - val_loss: 0.7773 - learning_rate: 5.0000e-05
# Epoch 12/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 68s 42ms/step - loss: 0.5360 - val_loss: 0.7678 - learning_rate: 5.0000e-05
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === Final Evaluation ===
# MSE: 0.00000000
# RMSE: 0.00005887
# QLIKE: 0.3694
# Directional Accuracy: 0.3660
# ✅ Model saved to models/out/lstm/config_v256d03.h5
# ✅ Scalers saved to models/out/lstm/config_v256d03_scalers.pkl

# %%
util.plot_prediction_vs_actual(
    df=test_df_lstm_v256d03,
    time_id=test_df_lstm_v256d03['time_id'].iloc[1],
    y_true_col="y_true",
    y_pred_col="y_pred"
)

util.plot_training_loss(history_lstm_v256d03)

# %%
snapshot_more_feature_df = util.add_features(snapshot_features_df)
feature_cols = ["wap", "spread_pct", "imbalance", "depth_ratio", "log_return",
                "log_wap_change", "rolling_std_logret", "spread_zscore", "volume_imbalance"]


subset_time_ids = snapshot_more_feature_df['time_id'].unique()[:100]
df_subset = snapshot_more_feature_df[snapshot_more_feature_df['time_id'].isin(subset_time_ids)].copy()
lstm_df_more_feature = util.generate_tick_sequences(df_subset, feature_cols)

# %%
model_lstm_more_feature, history_lstm_more_feature, test_df_lstm_more_feature = lstm.config_v256d03_more_feature(lstm_df_more_feature)
# Out:
# Epoch 1/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 74s 44ms/step - loss: 0.6172 - val_loss: 0.7495 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5628 - val_loss: 0.7585 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5538 - val_loss: 0.7403 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5497 - val_loss: 0.7395 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5468 - val_loss: 0.7586 - learning_rate: 1.0000e-04
# Epoch 6/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5447 - val_loss: 0.7506 - learning_rate: 1.0000e-04
# Epoch 7/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5428 - val_loss: 0.7443 - learning_rate: 1.0000e-04
# Epoch 8/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5402 - val_loss: 0.7377 - learning_rate: 1.0000e-04
# Epoch 9/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5394 - val_loss: 0.7591 - learning_rate: 1.0000e-04
# Epoch 10/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - loss: 0.5363 - val_loss: 0.7575 - learning_rate: 1.0000e-04
# Epoch 11/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - loss: 0.5359 - val_loss: 0.7713 - learning_rate: 1.0000e-04
# Epoch 12/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 75s 46ms/step - loss: 0.5427 - val_loss: 0.7590 - learning_rate: 1.0000e-04
# Epoch 13/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 75s 46ms/step - loss: 0.5321 - val_loss: 0.7612 - learning_rate: 1.0000e-04
# Epoch 14/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 74s 45ms/step - loss: 0.5264 - val_loss: 0.7510 - learning_rate: 5.0000e-05
# Epoch 15/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - loss: 0.5227 - val_loss: 0.7556 - learning_rate: 5.0000e-05
# Epoch 16/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 75s 46ms/step - loss: 0.5200 - val_loss: 0.7510 - learning_rate: 5.0000e-05
# Epoch 17/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 76s 47ms/step - loss: 0.5211 - val_loss: 0.7533 - learning_rate: 5.0000e-05
# Epoch 18/50
# 1629/1629 ━━━━━━━━━━━━━━━━━━━━ 77s 47ms/step - loss: 0.5186 - val_loss: 0.7564 - learning_rate: 5.0000e-05
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === Final Evaluation ===
# MSE: 0.00000000
# RMSE: 0.00005894
# QLIKE: 0.3565
# Directional Accuracy: 0.3616
# ✅ Model saved to models/out/lstm/config_v256d03_more_feature.h5
# ✅ Scalers saved to models/out/lstm/config_v256d03_more_feature_scalers.pkl

# %%
util.plot_prediction_vs_actual(
    df=test_df_lstm_more_feature,
    time_id=test_df_lstm_more_feature['time_id'].iloc[1],
    y_true_col="y_true",
    y_pred_col="y_pred"
)

util.plot_training_loss(history_lstm_more_feature)

# %%
import models.garch as garch
importlib.reload(garch)

selected_ids = rolling_features_df["time_id"].drop_duplicates().sort_values().iloc[:100]

rolling_subset = rolling_features_df[rolling_features_df["time_id"].isin(selected_ids)].reset_index(drop=True)
snapshot_subset = snapshot_features_df[snapshot_features_df["time_id"].isin(selected_ids)].reset_index(drop=True)

print(rolling_subset.keys())
print(snapshot_subset.keys())
# Out:
# Index(['stock_id', 'time_id', 'start_time', 'wap_mean', 'wap_std', 'wap_max',
#        'wap_min', 'spread_pct_mean', 'spread_pct_std', 'spread_pct_max',
#        'spread_pct_min', 'imbalance_mean', 'imbalance_std', 'imbalance_max',
#        'imbalance_min', 'depth_ratio_mean', 'depth_ratio_std',
#        'depth_ratio_max', 'depth_ratio_min', 'log_return_mean',
#        'log_return_std', 'log_return_max', 'log_return_min',
#        'realized_volatility', 'datetime'],
#       dtype='object')
# Index(['stock_id', 'time_id', 'seconds_in_bucket', 'bid_price1', 'ask_price1',
#        'bid_price2', 'ask_price2', 'bid_size1', 'ask_size1', 'bid_size2',
#        'ask_size2', 'mid_price', 'wap', 'bid_ask_spread', 'spread_pct',
#        'imbalance', 'depth_ratio', 'log_return'],
#       dtype='object')

# %%
importlib.reload(garch)

start = time.time()
model, result_df = garch.baseline(rolling_subset, snapshot_subset)
elapsed = time.time() - start

print(f"GARCH Baseline computation time: {elapsed:.2f} seconds")
# Out:
# python(15365) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Running ARMA-GARCH forecast...
# Processing: 100%|██████████| 14392/14392 [01:50<00:00, 130.03it/s]
# === ARMA-GARCH Baseline Evaluation (on test set) ===
# MSE: 0.00000005
# RMSE: 0.00021417
# QLIKE: 3.5359
# Directional Accuracy: 0.5025
# Success Rate: 13073/14392
# ✅ GARCH model saved to models/out/garch/baseline.pkl
# GARCH Baseline computation time: 110.73 seconds

# %%
util.plot_prediction_vs_actual(
    df=result_df,
    time_id=result_df['time_id'].iloc[1],
    y_true_col="y_true",
    y_pred_col="y_pred"
)

# %%
importlib.reload(garch)
# running a grid search over GARCH(p, q) models to find the best combination of p and q that minimizes error
model_garch_grid, result_df_garch_grid = garch.baseline_grid(
    rolling_df=rolling_subset,
    full_df=snapshot_subset,
    p_values=[1, 2, 3], 
    q_values=[1, 2, 3],
    scale=1000000
)
# Out:
# 🔍 Grid search over (p, q) combinations: [(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)]
#
# ▶ Evaluating GARCH(1,1)
# GARCH(1,1): 100%|██████████| 14392/14392 [01:51<00:00, 129.24it/s]
#     → RMSE = 0.00021417, QLIKE = 3.5359, Directional Accuracy = 0.5025
#
# ▶ Evaluating GARCH(1,2)
# GARCH(1,2): 100%|██████████| 14392/14392 [02:33<00:00, 93.95it/s]
#     → RMSE = 0.00021420, QLIKE = 3.5362, Directional Accuracy = 0.5064
#
# ▶ Evaluating GARCH(1,3)
# GARCH(1,3):   1%|          | 72/14392 [00:00<00:20, 685.14it/s]/Users/kang/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# GARCH(1,3):  12%|█▏        | 1709/14392 [00:20<03:03, 69.00it/s] /Users/kang/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# GARCH(1,3):  16%|█▌        | 2304/14392 [00:28<02:04, 96.98it/s] /Users/kang/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# GARCH(1,3):  40%|███▉      | 5710/14392 [01:14<02:24, 60.09it/s] /Users/kang/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# GARCH(1,3):  41%|████▏     | 5961/14392 [01:17<01:46, 78.94it/s] /Users/kang/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# GARCH(1,3):  90%|████████▉ | 12894/14392 [02:51<00:19, 75.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 importlib.reload(garch)
#       2 # running a grid search over GARCH(p, q) models to find the best combination of p and q that minimizes error
# ----> 3 model_garch_grid, result_df_garch_grid = garch.baseline_grid(
#       4     rolling_df=rolling_subset,
#       5     full_df=snapshot_subset,
#       6     p_values=[1, 2, 3],
#       7     q_values=[1, 2, 3],
#       8     scale=1000000
#       9 )
#
# File ~/Projects/volatility-analysis/models/garch.py:166, in baseline_grid(rolling_df, full_df, scale, train_ratio, p_values, q_values)
#     164 try:
#     165     model = arch_model(train_returns, mean="ARX", lags=1, vol="GARCH", p=p, q=q)
# --> 166     res = model.fit(disp="off")
#     167     last_model = res
#     169     forecast = res.forecast(horizon=H)
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:750, in ARCHModel.fit(self, update_freq, disp, starting_values, cov_type, show_warning, first_obs, last_obs, tol, options, backcast)
#     744 with warnings.catch_warnings():
#     745     warnings.filterwarnings(
#     746         "ignore",
#     747         "Values in x were outside bounds during a minimize step",
#     748         RuntimeWarning,
#     749     )
# --> 750     opt = minimize(
#     751         func,
#     752         sv,
#     753         args=args,
#     754         method="SLSQP",
#     755         bounds=bounds,
#     756         constraints=ineq_constraints,
#     757         tol=tol,
#     758         callback=_callback,
#     759         options=options,
#     760     )
#     762 if show_warning:
#     763     warnings.filterwarnings("always", "", ConvergenceWarning)
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_minimize.py:750, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#     749 elif meth == 'slsqp':
# --> 750     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     751                           constraints, callback=callback, **options)
#     752 elif meth == 'trust-constr':
#     753     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     754                                        bounds, constraints,
#     755                                        callback=callback, **options)
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:439, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     436     c = _eval_constraint(x, cons)
#     438 if mode == -1:  # gradient evaluation required
# --> 439     g = append(wrapped_grad(x), 0.0)
#     440     a = _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     442 if majiter > majiter_prev:
#     443     # call callback if major iteration has incremented
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_optimize.py:305, in _clip_x_for_func.<locals>.eval(x)
#     303 def eval(x):
#     304     x = _check_clip_x(x, bounds)
# --> 305     return func(x)
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:332, in ScalarFunction.grad(self, x)
#     330 if not np.array_equal(x, self.x):
#     331     self._update_x(x)
# --> 332 self._update_grad()
#     333 return self.g
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:48, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      46 def wrapped1(x, f0=None):
#      47     ncalls[0] += 1
# ---> 48     return approx_derivative(
#      49         fun, x, f0=f0, **finite_diff_options
#      50     )
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:523, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     520     use_one_sided = False
#     522 if sparsity is None:
# --> 523     return _dense_difference(fun_wrapped, x0, f0, h,
#     524                              use_one_sided, method)
#     525 else:
#     526     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:596, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     594     x1[i] += h[i]
#     595     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 596     df = fun(x1) - f0
#     597 elif method == '3-point' and use_one_sided[i]:
#     598     x1[i] += h[i]
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:474, in approx_derivative.<locals>.fun_wrapped(x)
#     471 if xp.isdtype(x.dtype, "real floating"):
#     472     x = xp.astype(x, x0.dtype)
# --> 474 f = np.atleast_1d(fun(x, *args, **kwargs))
#     475 if f.ndim > 1:
#     476     raise RuntimeError("`fun` return value has "
#     477                        "more than 1 dimension.")
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:440, in ARCHModel._loglikelihood(self, parameters, sigma2, backcast, var_bounds, individual)
#     437 _callback_info["count"] += 1
#     439 # 1. Resids
# --> 440 mp, vp, dp = self._parse_parameters(parameters)
#     441 resids = np.asarray(self.resids(mp), dtype=float)
#     443 # 2. Compute sigma2 using VolatilityModel
#
# File ~/Projects/volatility-analysis/.conda/lib/python3.11/site-packages/arch/univariate/base.py:472, in ARCHModel._parse_parameters(self, x)
#     470 """Return the parameters of each model in a tuple"""
#     471 x = np.asarray(x, dtype=float)
# --> 472 km, kv = int(self.num_params), int(self.volatility.num_params)
#     473 return x[:km], x[km : km + kv], x[km + kv :]
#
# KeyboardInterrupt:

# %%
util.plot_prediction_vs_actual(
    df=result_df_garch_grid,
    time_id=result_df_garch_grid['time_id'].iloc[1],
    y_true_col="y_true",
    y_pred_col="y_pred"
)
